# %% [markdown]
# <a href="https://colab.research.google.com/github/RMoulla/PYK_Mai/blob/main/Copie_de_TP_Bases_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Travaux pratiques : Bases de Python**

# %% [markdown]
# ## Première commande

# %%
# Première commande : afficher bonjour
print("Bonjour Bob")
# Out:
# Bonjour Bob

# %% [markdown]
# ## Assignation

# %%
# la variable a prend la valeur 2

a = 2
print(a)
# Out:
# 2

# %%
# Ajouter 1 à a

a + 1
# Out:
# 3

# %%
# La variable b prend la valeur 3

b = 3
print(b)
# Out:
# 3

# %%
# Calculer la somme de a et b

a + b
# Out:
# 5

# %%
# Définir c comme une chaîne de caractère

c = "Bonjour"
print(c)
# Out:
# Bonjour

# %%
# Définir d comme une chaîne de caractère

d = " Alice"
print(d)
# Out:
#  Alice

# %%
# Calculer le produit entre a et c

print(a*c)
# Out:
# BonjourBonjour

# %%
# La somme de c et d
print(c + d)
# Out:
# Bonjour Alice

# %%
# Ecraser la valeur d'une variable

d = " Bob"
print(c + d)
# Out:
# Bonjour Bob

# %%
# Typologies des variables

print(type(a))
print(type(c))
print(type(3.14))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ## Les conditions

# %%
# si a est supérieur à 1 afficher "a est supérieur à 1"

if a > 1:
   print("a est supérieur à 1")
# Out:
# a est supérieur à 1

# %%
# Si a est supérieur à 3 afficher "à supérieur à 3"
# sinon afficher "a est inférieur ou égal à 3"

if a > 3:
    print("a est supérieur à 3")
else:
    print("a est inférieur ou égal à 3")
# Out:
# a est inférieur ou égal à 3

# %%
# Si a est égal à 2 afficher "a est égal à 2"

if a == 2:
    print("a est égal à 2")
# Out:
# a est égal à 2

# %%
# Condition complexe :
# Si a n'est pas égal à 1
# et si a est inférieur à 3
# afficher a est inférieur à 3

if a != 1 and a < 3:
    print("a est inférieur à 3")
# Out:
# a est inférieur à 3

# %%
# Si a est différent de 1
# ou si a est inférieur 0
# afficher "Bonjour"

if a != 1 or a < 0:
    print("Bonjour")
# Out:
# Bonjour

# %%
# Si a est égal à 1 afficher "a est égal à 1"
# sinon si a est inférieur à 1 afficher "a est inférieur à 1"
# sinon si a est supérieur à 1 afficher "a est supérieur à 1"

if a == 1:
  print("a est égal à 1")
elif a < 1:
  print("a est inférieur à 1")
else:
  print("a est supérieur à 1")
# Out:
# a est supérieur à 1

# %% [markdown]
# ## Boucles itératives `for`

# %%
# Boucle for qui calcule les carrés des nombres de ma_liste

ma_liste = [1, 2, 3, 4, 5]

for iterateur in ma_liste:
  print(iterateur**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Les fonctions

# %%
# Fonction de base en Python

def ma_fonction():
  print("Bonjour")

# %%
ma_fonction()
# Out:
# Bonjour

# %%
# Fonction avec argument, qui calcule le carré d'un nombre

def carre(x):
  c = x**2
  return c

# %%
carre(3)
# Out:
# 9

# %%
# Fonction avec deux arguments a et b qui calcule le produit

def produit(a, b):
  return a*b

# %%
produit(3,4)
# Out:
# 12

# %% [markdown]
# ## Les listes

# %%
# Définir une liste

ma_liste = [10, 20, 40, 20, 5]

print(ma_liste)
# Out:
# [10, 20, 40, 20, 5]

# %%
# Accéder au premier élément de la liste

ma_liste[0]
# Out:
# 10

# %%
# Accéder au deuxième élément de la liste

ma_liste[1]
# Out:
# 20

# %%
# Accéder au dernier élément de la liste

ma_liste[-1]
# Out:
# 5

# %%
# Accéder aux plusieurs éléments en fonction de l'index

ma_liste[1:3]
# Out:
# [20, 40]

# %%
# Modifier un élément d'une liste

ma_liste[0] = 15
print(ma_liste)
# Out:
# [15, 20, 40, 20, 5]

# %%
# Insérer un élément dans une liste

ma_liste.insert(2, 35)
print(ma_liste)
# Out:
# [15, 20, 35, 40, 20, 5]

# %%
# Ajouter un élément à la dernière position

ma_liste.append(20)
print(ma_liste)
# Out:
# [15, 20, 35, 40, 20, 5, 20]

# %%
# Supprimer un élément d'une liste avec pop

ma_liste.pop(2)
print(ma_liste)
# Out:
# [15, 20, 40, 20, 5, 20]

# %%
# Supprimer l'élément 20

ma_liste.remove(20)
print(ma_liste)
# Out:
# [15, 40, 20, 5, 20]

# %%
# Enlever tous les éléments dont la valeur est 20 de la liste
for i in ma_liste:
  if i == 20:
    ma_liste.remove(i)

print(ma_liste)
# Out:
# [15, 40, 5]

# %%
# Ordonner une liste

ma_liste.sort()
print(ma_liste)
# Out:
# [5, 15, 40]

# %%
# Inverser l'ordre des éléments

ma_liste.reverse()
print(ma_liste)
# Out:
# [40, 15, 5]

# %%
# Ajouter une liste à une liste liste2 existante

liste2 = ["a", 40, "Bob"]
ma_liste.extend(liste2)
print(ma_liste)
# Out:
# [40, 15, 5, 'a', 40, 'Bob']

# %%
# Copier une liste

ma_copie = ma_liste
print(ma_copie)
# Out:
# [40, 15, 5, 'a', 40, 'Bob']

# %%
# Enlever le dernier élément de ma_copie

ma_copie.pop()
print(ma_copie)
# Out:
# [40, 15, 5, 'a', 40]

# %%
print(ma_liste)
# Out:
# [40, 15, 5, 'a', 40]

# %%
# Copier une liste avec copy

ma_copie = ma_liste.copy()
print(ma_copie)
# Out:
# [40, 15, 5, 'a', 40]

# %%
ma_copie.pop()
print(ma_copie)
print(ma_liste)
# Out:
# [40, 15, 5, 'a']
# [40, 15, 5, 'a', 40]

# %%
# Calculer les carrés d'une liste et sauvegarder dans liste_carre

ma_liste = [1, 2, 3, 4, 5]

liste_carre = []

for i in ma_liste:
  liste_carre.append(i**2)

print(liste_carre)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Calculer les carrés avec une comprehension de liste

liste_carre = [i**2 for i in ma_liste]
print(liste_carre)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Les dictionnaires

# %%
# Définir un dictionnaire avec {}

mon_dict = {"Nom" : "Alice", "Age" : 38, "Ville" : "Lyon"}
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 38, 'Ville': 'Lyon'}

# %%
# Accéder à la valeur de Age

mon_dict["Age"]
# Out:
# 38

# %%
# Modifier la valeur de l'âge

mon_dict["Age"] = 39
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 39, 'Ville': 'Lyon'}

# %%
# Ajouter une clé profession

mon_dict["Profession"] = "Ingénieur"
print(mon_dict)
# Out:
# {'Nom': 'Alice', 'Age': 39, 'Ville': 'Lyon', 'Profession': 'Ingénieur'}

# %%
# Récupérer les clés du dictionnaire

print(mon_dict.keys())
# Out:
# dict_keys(['Nom', 'Age', 'Ville', 'Profession'])

# %%
# Sauvegarder les clés d'un dictionnaire dans une liste
mes_cles = list(mon_dict.keys())
print(mes_cles)
# Out:
# ['Nom', 'Age', 'Ville', 'Profession']

# %%
mes_cles[0]
# Out:
# 'Nom'

# %%
# Sauvegarder les valeurs d'un dictionnaire dans une liste
mes_valeurs = list(mon_dict.values())
print(mes_valeurs)
# Out:
# ['Alice', 39, 'Lyon', 'Ingénieur']

# %%
# Créer un dictionnaire à partir de deux listes

cles = ["Nom", "Age", "Ville"]
valeurs = ["Bob", 42, "Paris"]

bob_dict = dict(zip(cles, valeurs))
print(bob_dict)
# Out:
# {'Nom': 'Bob', 'Age': 42, 'Ville': 'Paris'}

# %% [markdown]
# ## Les dataframes

# %%
# Créer un dataframe

import pandas as pd

df = pd.DataFrame(
    {"Nom" : ["Alice", "Bob", "Sophie"],
     "Age" : [39, 42, 25],
     "Ville" : ["Lyon", "Paris", "Lyon"]
    }
    )
df
# Out:
#       Nom  Age  Ville
# 0   Alice   39   Lyon
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Afficher les noms des colonnes

df.columns
# Out:
# Index(['Nom', 'Age', 'Ville'], dtype='object')

# %%
# Afficher les valeurs de la colonne Nom

df['Nom']
# Out:
# 0     Alice
# 1       Bob
# 2    Sophie
# Name: Nom, dtype: object

# %%
# Extraire un sous-dataframe

sub_df = df[['Nom', 'Age']]

sub_df
# Out:
#       Nom  Age
# 0   Alice   39
# 1     Bob   42
# 2  Sophie   25

# %%
# Affichier les deux premières lignes

df.head(2)
# Out:
#      Nom  Age  Ville
# 0  Alice   39   Lyon
# 1    Bob   42  Paris

# %%
# Afficher les deux dernières lignes

df.tail(2)
# Out:
#       Nom  Age  Ville
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Afficher la première ligne

df.iloc[0]
# Out:
# Nom      Alice
# Age         39
# Ville     Lyon
# Name: 0, dtype: object

# %%
# Afficher les lignes où l'âge est supérieur à 30 ans

df[df['Age'] > 30]
# Out:
#      Nom  Age  Ville
# 0  Alice   39   Lyon
# 1    Bob   42  Paris

# %%
# Afficher les lignes où Ville est Lyon

df[df['Ville'] == "Lyon"]
# Out:
#       Nom  Age Ville
# 0   Alice   39  Lyon
# 2  Sophie   25  Lyon

# %%
# Créer une copie de df
df_copie = df.copy()

# Enlever la colonne Ville de df_copie

df_copie.drop(columns=['Ville'], inplace=True)

# %%
df_copie
# Out:
#       Nom  Age
# 0   Alice   39
# 1     Bob   42
# 2  Sophie   25

# %%
df
# Out:
#       Nom  Age  Ville
# 0   Alice   39   Lyon
# 1     Bob   42  Paris
# 2  Sophie   25   Lyon

# %%
# Sauvegarder df sous format csv

df.to_csv('Mes_donnees.csv')
